# %%
import pandas as pd
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

BASE_DIR = Path(os.getcwd()).resolve().parent

DEFAULT_FILE_PATH = BASE_DIR/'data'/'messy_ecommerce_sales_data.csv'

df = pd.read_csv(DEFAULT_FILE_PATH)

# %% [markdown]
# # Overview

# %% [markdown]
# - info data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              103 non-null    int64
#  1    Customer_Name  103 non-null    object
#  2   Order_ID        103 non-null    object
#  3   Order_Date      103 non-null    object
#  4   Product         103 non-null    object
#  5    Category       95 non-null     object
#  6   Quantity        98 non-null     object
#  7   Price           98 non-null     object
#  8   Payment_Method  103 non-null    object
#  9   Status          103 non-null    object
#  10  Total           89 non-null     float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 9.0+ KB

# %% [markdown]
# In general, all data is coerced to the object type

# %%
df.isnull().sum()
# Out:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#       ID  Customer_Name   Order_ID Order_Date     Product    Category  \
# 102  146   Customer_146  ORD-32755   7/9/2025  Basketball  electronic
#
#     Quantity   Price Payment_Method      Status    Total
# 102        2  705.42  Bank Transfer  Processing  1410.84

# %% [markdown]
# The number of loop iterations is only 1.

# %%
df.describe()
# Out:
#                ID         Total
# count  103.000000     89.000000
# mean   149.640777   1232.949101
# std     28.704326   2605.471455
# min    100.000000 -20000.000000
# 25%    125.500000    582.130000
# 50%    149.000000   1138.760000
# 75%    174.500000   2153.400000
# max    199.000000   4722.700000

# %%
categorical_cols = df.select_dtypes(include ='object').columns
for col in categorical_cols:
    print(f"\n{col}: {df[col].unique()} unique value")
    print(df[col].value_counts().head(10))
# Out:
#  Customer_Name: ['Customer_100' 'Customer_101' 'Customer_102' 'Customer_103'
#  'Customer_104' 'Customer_105' 'Customer_106' 'Customer_107'
#  'Customer_108' 'Customer_109' 'Customer_110' 'Customer_111'
#  'Customer_112' 'Customer_113' 'Customer_114' 'Customer_115'
#  'Customer_116' 'Customer_117' 'Customer_118' 'Customer_119'
#  'Customer_120' 'Customer_121' 'Customer_122' 'Customer_123'
#  'Customer_124' 'Customer_125' 'Customer_126' 'Customer_127'
#  'Customer_128' 'Customer_129' 'Customer_130' 'Customer_131'
#  'Customer_132' 'Customer_133' 'Customer_134' 'Customer_135'
#  'Customer_136' 'Customer_137' 'Customer_138' 'Customer_139'
#  'Customer_140' 'Customer_141' 'Customer_142' 'Customer_143'
#  'Customer_144' 'Customer_145' 'Customer_146' 'Customer_147'
#  'Customer_148' 'Customer_149' 'Customer_150' 'Customer_151'
#  'Customer_152' 'Customer_153' 'Customer_154' 'Customer_155'
#  'Customer_156' 'Customer_157' 'Customer_158' 'Customer_159'
# ...

# %% [markdown]
# Quick visualize

# %%
sns.histplot(df['Sales'] if 'Sales' in df.columns else df['Total'])
plt.title("Distribution of Sales")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
